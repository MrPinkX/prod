# %%
import pandas as pd


df = pd.read_excel("instructions_4-53_appendix01inst4-53.xlsx")

# %%
from sqlalchemy import create_engine


# Create an engine to connect to the database (replace details accordingly)
engine = create_engine('sqlite:///d.db')

# Save DataFrame to SQL with table name 'my_table'
df.to_sql('my_table', con=engine, if_exists='replace')
# Out:
# 6050

# %%
df.to_sql()
# Out:
#              ברקוד       מותג       יצרן                           שם מוצר  \
# 0     1.258200e+05  משק יעקבס  משק יעקבס           1258200 גבינת שמנת 2ק"ג
# 1     1.302480e+05  מצות אביב    500 גרם                       קמח מצה חמץ
# 2     1.306060e+05  מצות אביב    200 גרם                       קמח מצה חמץ
# 3     2.121730e+05     מנעמים     מנעמים            ופל בטעם שוקולד 500 גר
# 4     2.124010e+05     מנעמים     מנעמים            ופל מצופית שוקו 400 גר
# ...            ...        ...        ...                               ...
# 6045  7.290000e+12     מנעמים     מנעמים              ופל שוקו 1ק"ג-מנעמים
# 6046  7.290000e+12     מנעמים     מנעמים        ופל מצופה ק.שוקו 20גר40Xיח
# 6047  2.942400e+10     מנעמים     מנעמים       גלילי מנ' אגוז 100 ג"ר בד"צ
# 6048  2.942400e+10     מנעמים     מנעמים       גלילי מנ' שוקו 100 ג"ר בד"צ
# 6049  7.290000e+12     מנעמים     מנעמים  גביעי גלידה  מנעמים 30 יח 120 גר
#
#      מועד עדכון ברקודים    סטאטוס סימון
# ...
